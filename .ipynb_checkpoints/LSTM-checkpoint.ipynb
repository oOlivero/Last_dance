# %%
#基于lstm量化交易系统
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()
from pandas_datareader import data as pdr
import datetime
import yfinance as yf
import json
# Out:
# WARNING:tensorflow:From C:\Users\ole\AppData\Roaming\Python\Python37\site-packages\tensorflow_core\python\compat\v2_compat.py:88: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# C:\Users\ole\Anaconda3\lib\site-packages\pandas_datareader\compat\__init__.py:7: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   from pandas.util.testing import assert_frame_equal

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"]="-1"

# %%
#配置火币API
from HuobiDMService import HuobiDM
from pprint import pprint

# 输入火币合约交易的api地址
URL = 'https://api.btcgateway.pro'
with open("../api_key.json",'r') as load_f:
    api_key = json.load(load_f)
    print(api_key)
#  输入 access_key 和 secret_key :
ACCESS_KEY = api_key['Access Key']
SECRET_KEY = api_key['Secret Key']


dm = HuobiDM(URL, ACCESS_KEY, SECRET_KEY)
# Out:
# {'Access Key': 'dqnh6tvdf3-384f7880-6d85af4e-d6ec5', 'Secret Key': '8ca950a5-3f6b29db-998ea629-08452'}

# %%
#配置matplotlib画图的符号
plt.rcParams['font.sans-serif'] = ['SimHei']  #显示中文
plt.rcParams['axes.unicode_minus']=False #用来正常显示坐标中的负号

def get_stock_data(name):
    try:
        yf.pdr_override()
    #实时股票数据
        finance = pdr.get_data_yahoo(name,start = datetime.datetime(2014,11,11),end = datetime.datetime(2020,3,11))  
        data = np.array(finance['Close']) #获取收盘价的数据
        data = data[::1] #获取这列的所有数据
        print('股票数据获取完成！！')
        return data
    except Exception:
        print('股票数据获取失败！！')
def get_coin_data(name):
    try:
        finance = pd.DataFrame(dm.get_contract_kline(symbol=name, period='5min', size=2000)['data'])
        data = np.array(finance['close']) #获取收盘价的数据
        data = data[::1] #获取这列的所有数据
        print(data)
        print('数据获取完成！！')
        return data
    except Exception:
        print('数据获取失败！！')

# %%
data = get_coin_data('BSV_CQ')
#以折线图展示导入的数据
fig =plt.figure()
#fig.add_subplot(1,2,1)
#plt.plot(data)
#plt.show()
normalize_data=(data-np.mean(data))/np.std(data)  #对数据进行标准化 （数据 - 均值）/（方差）
normalize_data=normalize_data[:,np.newaxis]       #增加数据的维度，使数据维度相同
# Out:
# [247.193 247.558 246.371 ... 118.511 124.887 117.286]
# 数据获取完成！！

# %%
print(data)
print(normalize_data)
# Out:
# [247.193 247.558 246.371 ... 118.511 124.887 117.286]
# [[ 1.24506664]
#  [ 1.25369476]
#  [ 1.22563565]
#  ...
#  [-1.7968064 ]
#  [-1.64608615]
#  [-1.82576378]]

# %%
#———————————————————形成训练集—————————————————————
#设置rnn网络的常量
time_step=20     #时间步 ，rnn每迭代20次，就向前推进一步
rnn_unit=10       # hidden layer units
batch_size=60     # 每一批训练多少个样例
input_size=1      # 输入层数维度
output_size=1     # 输出层数维度
lr=0.0006         # 学习率
train_x,train_y=[],[]   #训练集
for i in range(len(normalize_data)-time_step-1):
    x=normalize_data[i:i+time_step]
    y=normalize_data[i+1:i+time_step+1]
    train_x.append(x.tolist())
    train_y.append(y.tolist()) 
# print(len(normalize_data))
# print(train_x)
# print(train_y)

# %%
#———————————————————定义神经网络变量—————————————————————

X=tf.placeholder(tf.float32, [None,time_step,input_size])    #每批次输入网络的tensor
Y=tf.placeholder(tf.float32, [None,time_step,output_size])   # 每批次tensor对应的标签
#输入层、输出层的权重和偏置
weights={
         'in':tf.Variable(tf.random_normal([input_size,rnn_unit])),
         'out':tf.Variable(tf.random_normal([rnn_unit,1]))
         }
biases={
        'in':tf.Variable(tf.constant(0.1,shape=[rnn_unit,])),
        'out':tf.Variable(tf.constant(0.1,shape=[1,]))
        }

# %%
#———————————————————定义lstm网络—————————————————————
def lstm(batch):      #参数：输入网络批次数目
    w_in=weights['in']
    b_in=biases['in']
    input=tf.reshape(X,[-1,input_size])  #需要将tensor转为2维进行计算，计算后的结果作为 隐藏层的输入
    input_rnn=tf.matmul(input,w_in)+b_in
    input_rnn=tf.reshape(input_rnn,[-1,time_step,rnn_unit])   #将tensor转为3维，作为 lstm cell的输入
    cell=tf.nn.rnn_cell.BasicLSTMCell(rnn_unit)
    init_state=cell.zero_state(batch,dtype=tf.float32)
    output_rnn,final_states=tf.nn.dynamic_rnn(cell, input_rnn,initial_state=init_state, dtype=tf.float32)
    output=tf.reshape(output_rnn,[-1,rnn_unit])  #作为输出层的输入
    w_out=weights['out']
    b_out=biases['out']
    pred=tf.matmul(output,w_out)+b_out
    return pred,final_states

# %%
#———————————————————对模型进行训练—————————————————————
def train_lstm():
    global batch_size
    with tf.variable_scope("sec_lstm"):
        pred,_=lstm(batch_size)
    #定义损失函数
    loss=tf.reduce_mean(tf.square(tf.reshape(pred,[-1])-tf.reshape(Y, [-1])))
    train_op=tf.train.AdamOptimizer(lr).minimize(loss)
    saver=tf.train.Saver(tf.global_variables())
    with tf.Session() as sess:
        sess.run(tf.global_variables_initializer())
        loss_list = [] #收集损失值
        for i in range(201): #模型训练的次数，We can increase the number of iterations to gain better result.
            step=0
            start=0
            end=start+batch_size
            while(end<len(train_x)):
                _,loss_=sess.run([train_op,loss],feed_dict={X:train_x[start:end],Y:train_y[start:end]})
                start+=batch_size
                end=start+batch_size
                #每训练10次保存一次参数
                if step%10==0:
                    print("Number of iterations:",i," loss:",loss_) #输出训练次数，输出损失值
                    print("model_save",saver.save(sess,'./model_save1/modle.ckpt')) #第二个参数是保存的地址，可以修改为自己本地的保存地址
                    #I run the code in windows 10,so use  'model_save1\\modle.ckpt'
                    #if you run it in Linux,please use  'model_save1/modle.ckpt'
                    loss_list.append(loss_)
                step+=1
        print("The train has finished")
        print(len(loss_list))
        sns.set_style(style = 'whitegrid') #详细参数看seaborn的API  http://seaborn.pydata.org/api.html
        #设置字体
        sns.set_context(context = 'poster',font_scale = 1)
        plt.figure(figsize = (20,20)) #图像大小为20*20英寸
        plt.plot(np.arange(0,len(loss_list)),loss_list,'+-',color = 'g')
        plt.title('Loss trend')
        plt.ylabel('Loss')

# %%
train_lstm() #对模型进行训练
# Out:
# WARNING:tensorflow:From <ipython-input-9-28872e6d4573>:8: BasicLSTMCell.__init__ (from tensorflow.python.ops.rnn_cell_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This class is equivalent as tf.keras.layers.LSTMCell, and will be replaced by that in Tensorflow 2.0.
# WARNING:tensorflow:From <ipython-input-9-28872e6d4573>:10: dynamic_rnn (from tensorflow.python.ops.rnn) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `keras.layers.RNN(cell)`, which is equivalent to this API
# WARNING:tensorflow:From C:\Users\ole\AppData\Roaming\Python\Python37\site-packages\tensorflow_core\python\ops\rnn_cell_impl.py:735: Layer.add_variable (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.add_weight` method instead.
# WARNING:tensorflow:From C:\Users\ole\AppData\Roaming\Python\Python37\site-packages\tensorflow_core\python\ops\rnn_cell_impl.py:739: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# Number of iterations: 0  loss: 0.82601404
# model_save ./model_save1/modle.ckpt
# Number of iterations: 0  loss: 0.045503363
# model_save ./model_save1/modle.ckpt
# Number of iterations: 0  loss: 0.016632188
# model_save ./model_save1/modle.ckpt
# Number of iterations: 0  loss: 0.6561073
# model_save ./model_save1/modle.ckpt
# Number of iterations: 1  loss: 0.22895202
# model_save ./model_save1/modle.ckpt
# Number of iterations: 1  loss: 0.0532228
# model_save ./model_save1/modle.ckpt
# Number of iterations: 1  loss: 0.009877825
# model_save ./model_save1/modle.ckpt
# Number of iterations: 1  loss: 0.30723754
# model_save ./model_save1/modle.ckpt
# Number of iterations: 2  loss: 0.13232344
# model_save ./model_save1/modle.ckpt
# Number of iterations: 2  loss: 0.03573965
# model_save ./model_save1/modle.ckpt
# Number of iterations: 2  loss: 0.004665287
# model_save ./model_save1/modle.ckpt
# Number of iterations: 2  loss: 0.18210997
# model_save ./model_save1/modle.ckpt
# Number of iterations: 3  loss: 0.0999094
# model_save ./model_save1/modle.ckpt
# Number of iterations: 3  loss: 0.020516597
# model_save ./model_save1/modle.ckpt
# Number of iterations: 3  loss: 0.002271337
# model_save ./model_save1/modle.ckpt
# Number of iterations: 3  loss: 0.13837986
# model_save ./model_save1/modle.ckpt
# Number of iterations: 4  loss: 0.08729385
# model_save ./model_save1/modle.ckpt
# Number of iterations: 4  loss: 0.011043515
# model_save ./model_save1/modle.ckpt
# Number of iterations: 4  loss: 0.0014856368
# model_save ./model_save1/modle.ckpt
# Number of iterations: 4  loss: 0.119896606
# model_save ./model_save1/modle.ckpt
# Number of iterations: 5  loss: 0.079785414
# model_save ./model_save1/modle.ckpt
# Number of iterations: 5  loss: 0.0062311776
# model_save ./model_save1/modle.ckpt
# Number of iterations: 5  loss: 0.0014018897
# model_save ./model_save1/modle.ckpt
# Number of iterations: 5  loss: 0.10958853
# model_save ./model_save1/modle.ckpt
# Number of iterations: 6  loss: 0.073687404
# model_save ./model_save1/modle.ckpt
# Number of iterations: 6  loss: 0.0039732256
# model_save ./model_save1/modle.ckpt
# Number of iterations: 6  loss: 0.0015400404
# model_save ./model_save1/modle.ckpt
# Number of iterations: 6  loss: 0.10272558
# model_save ./model_save1/modle.ckpt
# Number of iterations: 7  loss: 0.06820622
# model_save ./model_save1/modle.ckpt
# Number of iterations: 7  loss: 0.0029855093
# model_save ./model_save1/modle.ckpt
# Number of iterations: 7  loss: 0.0017142713
# model_save ./model_save1/modle.ckpt
# Number of iterations: 7  loss: 0.0977764
# model_save ./model_save1/modle.ckpt
# Number of iterations: 8  loss: 0.062947035
# model_save ./model_save1/modle.ckpt
# Number of iterations: 8  loss: 0.0026306268
# model_save ./model_save1/modle.ckpt
# Number of iterations: 8  loss: 0.001859831
# model_save ./model_save1/modle.ckpt
# Number of iterations: 8  loss: 0.0939248
# model_save ./model_save1/modle.ckpt
# Number of iterations: 9  loss: 0.05769548
# model_save ./model_save1/modle.ckpt
# Number of iterations: 9  loss: 0.002589556
# model_save ./model_save1/modle.ckpt
# Number of iterations: 9  loss: 0.001959972
# model_save ./model_save1/modle.ckpt
# Number of iterations: 9  loss: 0.0906627
# model_save ./model_save1/modle.ckpt
# Number of iterations: 10  loss: 0.0523257
# model_save ./model_save1/modle.ckpt
# Number of iterations: 10  loss: 0.0026949244
# model_save ./model_save1/modle.ckpt
# Number of iterations: 10  loss: 0.0020144398
# model_save ./model_save1/modle.ckpt
# Number of iterations: 10  loss: 0.087617874
# model_save ./model_save1/modle.ckpt
# Number of iterations: 11  loss: 0.04682363
# model_save ./model_save1/modle.ckpt
# Number of iterations: 11  loss: 0.002849527
# model_save ./model_save1/modle.ckpt
# Number of iterations: 11  loss: 0.002027873
# model_save ./model_save1/modle.ckpt
# Number of iterations: 11  loss: 0.0845061
# model_save ./model_save1/modle.ckpt
# Number of iterations: 12  loss: 0.04130657
# model_save ./model_save1/modle.ckpt
# Number of iterations: 12  loss: 0.002995701
# model_save ./model_save1/modle.ckpt
# Number of iterations: 12  loss: 0.0020060858
# model_save ./model_save1/modle.ckpt
# Number of iterations: 12  loss: 0.0811736
# model_save ./model_save1/modle.ckpt
# Number of iterations: 13  loss: 0.03602292
# model_save ./model_save1/modle.ckpt
# Number of iterations: 13  loss: 0.0031067163
# model_save ./model_save1/modle.ckpt
# Number of iterations: 13  loss: 0.001954277
# model_save ./model_save1/modle.ckpt
# Number of iterations: 13  loss: 0.07764624
# model_save ./model_save1/modle.ckpt
# Number of iterations: 14  loss: 0.03128631
# model_save ./model_save1/modle.ckpt
# Number of iterations: 14  loss: 0.003181413
# model_save ./model_save1/modle.ckpt
# Number of iterations: 14  loss: 0.0018755886
# model_save ./model_save1/modle.ckpt
# Number of iterations: 14  loss: 0.07407687
# model_save ./model_save1/modle.ckpt
# Number of iterations: 15  loss: 0.027350876
# model_save ./model_save1/modle.ckpt
# Number of iterations: 15  loss: 0.0032284602
# model_save ./model_save1/modle.ckpt
# Number of iterations: 15  loss: 0.0017711329
# model_save ./model_save1/modle.ckpt
# Number of iterations: 15  loss: 0.07062201
# model_save ./model_save1/modle.ckpt
# Number of iterations: 16  loss: 0.024294907
# model_save ./model_save1/modle.ckpt
# Number of iterations: 16  loss: 0.003245922
# model_save ./model_save1/modle.ckpt
# Number of iterations: 16  loss: 0.0016441382
# model_save ./model_save1/modle.ckpt
# Number of iterations: 16  loss: 0.06737183
# model_save ./model_save1/modle.ckpt
# Number of iterations: 17  loss: 0.022029022
# model_save ./model_save1/modle.ckpt
# Number of iterations: 17  loss: 0.0032198937
# model_save ./model_save1/modle.ckpt
# Number of iterations: 17  loss: 0.001503641
# model_save ./model_save1/modle.ckpt
# Number of iterations: 17  loss: 0.06437685
# model_save ./model_save1/modle.ckpt
# Number of iterations: 18  loss: 0.020382
# model_save ./model_save1/modle.ckpt
# Number of iterations: 18  loss: 0.0031408255
# model_save ./model_save1/modle.ckpt
# Number of iterations: 18  loss: 0.001361722
# model_save ./model_save1/modle.ckpt
# Number of iterations: 18  loss: 0.061651077
# model_save ./model_save1/modle.ckpt
# Number of iterations: 19  loss: 0.019173114
# model_save ./model_save1/modle.ckpt
# Number of iterations: 19  loss: 0.0030130018
# model_save ./model_save1/modle.ckpt
# Number of iterations: 19  loss: 0.0012280971
# model_save ./model_save1/modle.ckpt
# Number of iterations: 19  loss: 0.059175957
# model_save ./model_save1/modle.ckpt
# Number of iterations: 20  loss: 0.018246071
# model_save ./model_save1/modle.ckpt
# Number of iterations: 20  loss: 0.0028514587
# model_save ./model_save1/modle.ckpt
# Number of iterations: 20  loss: 0.001107954
# model_save ./model_save1/modle.ckpt
# Number of iterations: 20  loss: 0.056913447
# model_save ./model_save1/modle.ckpt
# Number of iterations: 21  loss: 0.017481634
# model_save ./model_save1/modle.ckpt
# Number of iterations: 21  loss: 0.002674453
# model_save ./model_save1/modle.ckpt
# Number of iterations: 21  loss: 0.0010028516
# model_save ./model_save1/modle.ckpt
# Number of iterations: 21  loss: 0.054824688
# model_save ./model_save1/modle.ckpt
# Number of iterations: 22  loss: 0.016799768
# model_save ./model_save1/modle.ckpt
# Number of iterations: 22  loss: 0.002497545
# model_save ./model_save1/modle.ckpt
# Number of iterations: 22  loss: 0.00091239007
# model_save ./model_save1/modle.ckpt
# Number of iterations: 22  loss: 0.052879035
# model_save ./model_save1/modle.ckpt
# Number of iterations: 23  loss: 0.016153542
# model_save ./model_save1/modle.ckpt
# Number of iterations: 23  loss: 0.0023312634
# model_save ./model_save1/modle.ckpt
# Number of iterations: 23  loss: 0.0008353827
# model_save ./model_save1/modle.ckpt
# Number of iterations: 23  loss: 0.051057503
# model_save ./model_save1/modle.ckpt
# Number of iterations: 24  loss: 0.015519606
# model_save ./model_save1/modle.ckpt
# Number of iterations: 24  loss: 0.0021812855
# model_save ./model_save1/modle.ckpt
# Number of iterations: 24  loss: 0.0007704344
# model_save ./model_save1/modle.ckpt
# Number of iterations: 24  loss: 0.049346842
# model_save ./model_save1/modle.ckpt
# Number of iterations: 25  loss: 0.014889463
# model_save ./model_save1/modle.ckpt
# Number of iterations: 25  loss: 0.0020496936
# model_save ./model_save1/modle.ckpt
# Number of iterations: 25  loss: 0.00071615505
# model_save ./model_save1/modle.ckpt
# Number of iterations: 25  loss: 0.047737364
# model_save ./model_save1/modle.ckpt
# Number of iterations: 26  loss: 0.0142628895
# model_save ./model_save1/modle.ckpt
# Number of iterations: 26  loss: 0.0019365827
# model_save ./model_save1/modle.ckpt
# Number of iterations: 26  loss: 0.00067120255
# model_save ./model_save1/modle.ckpt
# Number of iterations: 26  loss: 0.046216525
# model_save ./model_save1/modle.ckpt
# Number of iterations: 27  loss: 0.01364384
# model_save ./model_save1/modle.ckpt
# Number of iterations: 27  loss: 0.001840752
# model_save ./model_save1/modle.ckpt
# Number of iterations: 27  loss: 0.00063428533
# model_save ./model_save1/modle.ckpt
# Number of iterations: 27  loss: 0.044774048
# model_save ./model_save1/modle.ckpt
# Number of iterations: 28  loss: 0.013037749
# model_save ./model_save1/modle.ckpt
# Number of iterations: 28  loss: 0.0017606161
# model_save ./model_save1/modle.ckpt
# Number of iterations: 28  loss: 0.00060416886
# model_save ./model_save1/modle.ckpt
# Number of iterations: 28  loss: 0.043396577
# model_save ./model_save1/modle.ckpt
# Number of iterations: 29  loss: 0.012450128
# model_save ./model_save1/modle.ckpt
# Number of iterations: 29  loss: 0.0016941911
# model_save ./model_save1/modle.ckpt
# Number of iterations: 29  loss: 0.0005797149
# model_save ./model_save1/modle.ckpt
# Number of iterations: 29  loss: 0.042076252
# model_save ./model_save1/modle.ckpt
# Number of iterations: 30  loss: 0.011885461
# model_save ./model_save1/modle.ckpt
# Number of iterations: 30  loss: 0.0016396214
# model_save ./model_save1/modle.ckpt
# Number of iterations: 30  loss: 0.0005599026
# model_save ./model_save1/modle.ckpt
# Number of iterations: 30  loss: 0.040802326
# model_save ./model_save1/modle.ckpt
# Number of iterations: 31  loss: 0.011346784
# model_save ./model_save1/modle.ckpt
# Number of iterations: 31  loss: 0.0015948723
# model_save ./model_save1/modle.ckpt
# Number of iterations: 31  loss: 0.0005438468
# model_save ./model_save1/modle.ckpt
# Number of iterations: 31  loss: 0.039572414
# model_save ./model_save1/modle.ckpt
# Number of iterations: 32  loss: 0.010835389
# model_save ./model_save1/modle.ckpt
# Number of iterations: 32  loss: 0.0015583105
# model_save ./model_save1/modle.ckpt
# Number of iterations: 32  loss: 0.00053079816
# model_save ./model_save1/modle.ckpt
# Number of iterations: 32  loss: 0.03837667
# model_save ./model_save1/modle.ckpt
# Number of iterations: 33  loss: 0.010351243
# model_save ./model_save1/modle.ckpt
# Number of iterations: 33  loss: 0.0015280658
# model_save ./model_save1/modle.ckpt
# Number of iterations: 33  loss: 0.0005201448
# model_save ./model_save1/modle.ckpt
# Number of iterations: 33  loss: 0.03722098
# model_save ./model_save1/modle.ckpt
# Number of iterations: 34  loss: 0.009893056
# model_save ./model_save1/modle.ckpt
# Number of iterations: 34  loss: 0.0015030688
# model_save ./model_save1/modle.ckpt
# Number of iterations: 34  loss: 0.00051139784
# model_save ./model_save1/modle.ckpt
# Number of iterations: 34  loss: 0.03608955
# model_save ./model_save1/modle.ckpt
# Number of iterations: 35  loss: 0.009459507
# model_save ./model_save1/modle.ckpt
# Number of iterations: 35  loss: 0.0014815491
# model_save ./model_save1/modle.ckpt
# Number of iterations: 35  loss: 0.00050420174
# model_save ./model_save1/modle.ckpt
# Number of iterations: 35  loss: 0.035005424
# model_save ./model_save1/modle.ckpt
# Number of iterations: 36  loss: 0.009048376
# model_save ./model_save1/modle.ckpt
# Number of iterations: 36  loss: 0.001463396
# model_save ./model_save1/modle.ckpt
# Number of iterations: 36  loss: 0.0004982706
# model_save ./model_save1/modle.ckpt
# Number of iterations: 36  loss: 0.033926237
# model_save ./model_save1/modle.ckpt
# Number of iterations: 37  loss: 0.008659279
# model_save ./model_save1/modle.ckpt
# Number of iterations: 37  loss: 0.0014462348
# model_save ./model_save1/modle.ckpt
# Number of iterations: 37  loss: 0.00049346295
# model_save ./model_save1/modle.ckpt
# Number of iterations: 37  loss: 0.032927003
# model_save ./model_save1/modle.ckpt
# Number of iterations: 38  loss: 0.008289025
# model_save ./model_save1/modle.ckpt
# Number of iterations: 38  loss: 0.0014321866
# model_save ./model_save1/modle.ckpt
# Number of iterations: 38  loss: 0.00048953283
# model_save ./model_save1/modle.ckpt
# Number of iterations: 38  loss: 0.03186857
# model_save ./model_save1/modle.ckpt
# Number of iterations: 39  loss: 0.00794049
# model_save ./model_save1/modle.ckpt
# Number of iterations: 39  loss: 0.001415682
# model_save ./model_save1/modle.ckpt
# Number of iterations: 39  loss: 0.00048658278
# model_save ./model_save1/modle.ckpt
# Number of iterations: 39  loss: 0.031013818
# model_save ./model_save1/modle.ckpt
# Number of iterations: 40  loss: 0.0076053278
# model_save ./model_save1/modle.ckpt
# Number of iterations: 40  loss: 0.0014058967
# model_save ./model_save1/modle.ckpt
# Number of iterations: 40  loss: 0.00048400165
# model_save ./model_save1/modle.ckpt
# Number of iterations: 40  loss: 0.029853376
# model_save ./model_save1/modle.ckpt
# Number of iterations: 41  loss: 0.0072972616
# model_save ./model_save1/modle.ckpt
# Number of iterations: 41  loss: 0.0013842585
# model_save ./model_save1/modle.ckpt
# Number of iterations: 41  loss: 0.0004827263
# model_save ./model_save1/modle.ckpt
# Number of iterations: 41  loss: 0.029398892
# model_save ./model_save1/modle.ckpt
# Number of iterations: 42  loss: 0.006985809
# model_save ./model_save1/modle.ckpt
# Number of iterations: 42  loss: 0.0013865335
# model_save ./model_save1/modle.ckpt
# Number of iterations: 42  loss: 0.0004802669
# model_save ./model_save1/modle.ckpt
# Number of iterations: 42  loss: 0.02762113
# model_save ./model_save1/modle.ckpt
# Number of iterations: 43  loss: 0.006730886
# model_save ./model_save1/modle.ckpt
# Number of iterations: 43  loss: 0.001340603
# model_save ./model_save1/modle.ckpt
# Number of iterations: 43  loss: 0.0004817677
# model_save ./model_save1/modle.ckpt
# Number of iterations: 43  loss: 0.028784333
# model_save ./model_save1/modle.ckpt
# Number of iterations: 44  loss: 0.0064066667
# model_save ./model_save1/modle.ckpt
# Number of iterations: 44  loss: 0.0013944651
# model_save ./model_save1/modle.ckpt
# Number of iterations: 44  loss: 0.0004753846
# model_save ./model_save1/modle.ckpt
# Number of iterations: 44  loss: 0.02432726
# model_save ./model_save1/modle.ckpt
# Number of iterations: 45  loss: 0.006292348
# model_save ./model_save1/modle.ckpt
# Number of iterations: 45  loss: 0.0012422897
# model_save ./model_save1/modle.ckpt
# Number of iterations: 45  loss: 0.00048893166
# model_save ./model_save1/modle.ckpt
# Number of iterations: 45  loss: 0.034508735
# model_save ./model_save1/modle.ckpt
# Number of iterations: 46  loss: 0.0058675944
# model_save ./model_save1/modle.ckpt
# Number of iterations: 46  loss: 0.0015529878
# model_save ./model_save1/modle.ckpt
# Number of iterations: 46  loss: 0.00046508442
# model_save ./model_save1/modle.ckpt
# Number of iterations: 46  loss: 0.026390247
# model_save ./model_save1/modle.ckpt
# Number of iterations: 47  loss: 0.006480239
# model_save ./model_save1/modle.ckpt
# Number of iterations: 47  loss: 0.0009870057
# model_save ./model_save1/modle.ckpt
# Number of iterations: 47  loss: 0.0005566016
# model_save ./model_save1/modle.ckpt
# Number of iterations: 47  loss: 0.11952796
# model_save ./model_save1/modle.ckpt
# Number of iterations: 48  loss: 0.006176974
# model_save ./model_save1/modle.ckpt
# Number of iterations: 48  loss: 0.0034308822
# model_save ./model_save1/modle.ckpt
# Number of iterations: 48  loss: 0.00049232115
# model_save ./model_save1/modle.ckpt
# Number of iterations: 48  loss: 0.1580116
# model_save ./model_save1/modle.ckpt
# Number of iterations: 49  loss: 0.005035035
# model_save ./model_save1/modle.ckpt
# Number of iterations: 49  loss: 0.0033692617
# model_save ./model_save1/modle.ckpt
# Number of iterations: 49  loss: 0.0006157856
# model_save ./model_save1/modle.ckpt
# Number of iterations: 49  loss: 0.1956369
# model_save ./model_save1/modle.ckpt
# Number of iterations: 50  loss: 0.04661073
# model_save ./model_save1/modle.ckpt
# Number of iterations: 50  loss: 0.0063506225
# model_save ./model_save1/modle.ckpt
# Number of iterations: 50  loss: 0.0024549635
# model_save ./model_save1/modle.ckpt
# Number of iterations: 50  loss: 0.060371768
# model_save ./model_save1/modle.ckpt
# Number of iterations: 51  loss: 0.009920569
# model_save ./model_save1/modle.ckpt
# Number of iterations: 51  loss: 0.0014972375
# model_save ./model_save1/modle.ckpt
# Number of iterations: 51  loss: 0.0008689338
# model_save ./model_save1/modle.ckpt
# Number of iterations: 51  loss: 0.05352283
# model_save ./model_save1/modle.ckpt
# Number of iterations: 52  loss: 0.030855544
# model_save ./model_save1/modle.ckpt
# Number of iterations: 52  loss: 0.0014067523
# model_save ./model_save1/modle.ckpt
# Number of iterations: 52  loss: 0.0009869129
# model_save ./model_save1/modle.ckpt
# Number of iterations: 52  loss: 0.027128886
# model_save ./model_save1/modle.ckpt
# Number of iterations: 53  loss: 0.014113516
# model_save ./model_save1/modle.ckpt
# Number of iterations: 53  loss: 0.0025420443
# model_save ./model_save1/modle.ckpt
# Number of iterations: 53  loss: 0.00053043145
# model_save ./model_save1/modle.ckpt
# Number of iterations: 53  loss: 0.030952752
# model_save ./model_save1/modle.ckpt
# Number of iterations: 54  loss: 0.007815682
# model_save ./model_save1/modle.ckpt
# Number of iterations: 54  loss: 0.0010685206
# model_save ./model_save1/modle.ckpt
# Number of iterations: 54  loss: 0.0005724432
# model_save ./model_save1/modle.ckpt
# Number of iterations: 54  loss: 0.028417876
# model_save ./model_save1/modle.ckpt
# Number of iterations: 55  loss: 0.0038334748
# model_save ./model_save1/modle.ckpt
# Number of iterations: 55  loss: 0.0015256667
# model_save ./model_save1/modle.ckpt
# Number of iterations: 55  loss: 0.0005501059
# model_save ./model_save1/modle.ckpt
# Number of iterations: 55  loss: 0.028063882
# model_save ./model_save1/modle.ckpt
# Number of iterations: 56  loss: 0.0037076154
# model_save ./model_save1/modle.ckpt
# Number of iterations: 56  loss: 0.0012802224
# model_save ./model_save1/modle.ckpt
# Number of iterations: 56  loss: 0.00051852595
# model_save ./model_save1/modle.ckpt
# Number of iterations: 56  loss: 0.026441041
# model_save ./model_save1/modle.ckpt
# Number of iterations: 57  loss: 0.0042498675
# model_save ./model_save1/modle.ckpt
# Number of iterations: 57  loss: 0.0011654182
# model_save ./model_save1/modle.ckpt
# Number of iterations: 57  loss: 0.0005216389
# model_save ./model_save1/modle.ckpt
# Number of iterations: 57  loss: 0.026123174
# model_save ./model_save1/modle.ckpt
# Number of iterations: 58  loss: 0.0036210874
# model_save ./model_save1/modle.ckpt
# Number of iterations: 58  loss: 0.0012856076
# model_save ./model_save1/modle.ckpt
# Number of iterations: 58  loss: 0.0005015153
# model_save ./model_save1/modle.ckpt
# Number of iterations: 58  loss: 0.024843551
# model_save ./model_save1/modle.ckpt
# Number of iterations: 59  loss: 0.0035644046
# model_save ./model_save1/modle.ckpt
# Number of iterations: 59  loss: 0.0011960141
# model_save ./model_save1/modle.ckpt
# Number of iterations: 59  loss: 0.0004925581
# model_save ./model_save1/modle.ckpt
# Number of iterations: 59  loss: 0.024311578
# model_save ./model_save1/modle.ckpt
# Number of iterations: 60  loss: 0.003593474
# model_save ./model_save1/modle.ckpt
# Number of iterations: 60  loss: 0.0011711471
# model_save ./model_save1/modle.ckpt
# Number of iterations: 60  loss: 0.00049057254
# model_save ./model_save1/modle.ckpt
# Number of iterations: 60  loss: 0.023449622
# model_save ./model_save1/modle.ckpt
# Number of iterations: 61  loss: 0.0034072446
# model_save ./model_save1/modle.ckpt
# Number of iterations: 61  loss: 0.0011762845
# model_save ./model_save1/modle.ckpt
# Number of iterations: 61  loss: 0.00047986984
# model_save ./model_save1/modle.ckpt
# Number of iterations: 61  loss: 0.022830212
# model_save ./model_save1/modle.ckpt
# Number of iterations: 62  loss: 0.0033317523
# model_save ./model_save1/modle.ckpt
# Number of iterations: 62  loss: 0.0011527593
# model_save ./model_save1/modle.ckpt
# Number of iterations: 62  loss: 0.00047560578
# model_save ./model_save1/modle.ckpt
# Number of iterations: 62  loss: 0.022115784
# model_save ./model_save1/modle.ckpt
# Number of iterations: 63  loss: 0.0032554718
# model_save ./model_save1/modle.ckpt
# Number of iterations: 63  loss: 0.001133346
# model_save ./model_save1/modle.ckpt
# Number of iterations: 63  loss: 0.00047109724
# model_save ./model_save1/modle.ckpt
# Number of iterations: 63  loss: 0.021566859
# model_save ./model_save1/modle.ckpt
# Number of iterations: 64  loss: 0.0031690768
# model_save ./model_save1/modle.ckpt
# Number of iterations: 64  loss: 0.0011213633
# model_save ./model_save1/modle.ckpt
# Number of iterations: 64  loss: 0.00046655815
# model_save ./model_save1/modle.ckpt
# Number of iterations: 64  loss: 0.020931931
# model_save ./model_save1/modle.ckpt
# Number of iterations: 65  loss: 0.003078339
# model_save ./model_save1/modle.ckpt
# Number of iterations: 65  loss: 0.0011066053
# model_save ./model_save1/modle.ckpt
# Number of iterations: 65  loss: 0.00046183515
# model_save ./model_save1/modle.ckpt
# Number of iterations: 65  loss: 0.020437088
# model_save ./model_save1/modle.ckpt
# Number of iterations: 66  loss: 0.0029986585
# model_save ./model_save1/modle.ckpt
# Number of iterations: 66  loss: 0.0010930483
# model_save ./model_save1/modle.ckpt
# Number of iterations: 66  loss: 0.00045808023
# model_save ./model_save1/modle.ckpt
# Number of iterations: 66  loss: 0.019871157
# model_save ./model_save1/modle.ckpt
# Number of iterations: 67  loss: 0.0029169377
# model_save ./model_save1/modle.ckpt
# Number of iterations: 67  loss: 0.0010778819
# model_save ./model_save1/modle.ckpt
# Number of iterations: 67  loss: 0.0004539579
# model_save ./model_save1/modle.ckpt
# Number of iterations: 67  loss: 0.01943202
# model_save ./model_save1/modle.ckpt
# Number of iterations: 68  loss: 0.0028398978
# model_save ./model_save1/modle.ckpt
# Number of iterations: 68  loss: 0.0010657986
# model_save ./model_save1/modle.ckpt
# Number of iterations: 68  loss: 0.0004502362
# model_save ./model_save1/modle.ckpt
# Number of iterations: 68  loss: 0.018912528
# model_save ./model_save1/modle.ckpt
# Number of iterations: 69  loss: 0.0027594396
# model_save ./model_save1/modle.ckpt
# Number of iterations: 69  loss: 0.0010516652
# model_save ./model_save1/modle.ckpt
# Number of iterations: 69  loss: 0.00044603535
# model_save ./model_save1/modle.ckpt
# Number of iterations: 69  loss: 0.018529195
# model_save ./model_save1/modle.ckpt
# Number of iterations: 70  loss: 0.0026848826
# model_save ./model_save1/modle.ckpt
# Number of iterations: 70  loss: 0.0010405342
# model_save ./model_save1/modle.ckpt
# Number of iterations: 70  loss: 0.00044230014
# model_save ./model_save1/modle.ckpt
# Number of iterations: 70  loss: 0.018038636
# model_save ./model_save1/modle.ckpt
# Number of iterations: 71  loss: 0.0026082941
# model_save ./model_save1/modle.ckpt
# Number of iterations: 71  loss: 0.0010263948
# model_save ./model_save1/modle.ckpt
# Number of iterations: 71  loss: 0.0004381357
# model_save ./model_save1/modle.ckpt
# Number of iterations: 71  loss: 0.01771766
# model_save ./model_save1/modle.ckpt
# Number of iterations: 72  loss: 0.0025382037
# model_save ./model_save1/modle.ckpt
# Number of iterations: 72  loss: 0.0010164299
# model_save ./model_save1/modle.ckpt
# Number of iterations: 72  loss: 0.0004344286
# model_save ./model_save1/modle.ckpt
# Number of iterations: 72  loss: 0.017231686
# model_save ./model_save1/modle.ckpt
# Number of iterations: 73  loss: 0.0024645166
# model_save ./model_save1/modle.ckpt
# Number of iterations: 73  loss: 0.0010021414
# model_save ./model_save1/modle.ckpt
# Number of iterations: 73  loss: 0.00043014725
# model_save ./model_save1/modle.ckpt
# Number of iterations: 73  loss: 0.01699228
# model_save ./model_save1/modle.ckpt
# Number of iterations: 74  loss: 0.0023981659
# model_save ./model_save1/modle.ckpt
# Number of iterations: 74  loss: 0.0009941333
# model_save ./model_save1/modle.ckpt
# Number of iterations: 74  loss: 0.00042637368
# model_save ./model_save1/modle.ckpt
# Number of iterations: 74  loss: 0.01646955
# model_save ./model_save1/modle.ckpt
# Number of iterations: 75  loss: 0.0023262156
# model_save ./model_save1/modle.ckpt
# Number of iterations: 75  loss: 0.0009787718
# model_save ./model_save1/modle.ckpt
# Number of iterations: 75  loss: 0.0004219232
# model_save ./model_save1/modle.ckpt
# Number of iterations: 75  loss: 0.016362954
# model_save ./model_save1/modle.ckpt
# Number of iterations: 76  loss: 0.0022649292
# model_save ./model_save1/modle.ckpt
# Number of iterations: 76  loss: 0.0009739069
# model_save ./model_save1/modle.ckpt
# Number of iterations: 76  loss: 0.0004181693
# model_save ./model_save1/modle.ckpt
# Number of iterations: 76  loss: 0.015716165
# model_save ./model_save1/modle.ckpt
# Number of iterations: 77  loss: 0.002194164
# model_save ./model_save1/modle.ckpt
# Number of iterations: 77  loss: 0.00095540384
# model_save ./model_save1/modle.ckpt
# Number of iterations: 77  loss: 0.00041358365
# model_save ./model_save1/modle.ckpt
# Number of iterations: 77  loss: 0.01587487
# model_save ./model_save1/modle.ckpt
# Number of iterations: 78  loss: 0.0021402473
# model_save ./model_save1/modle.ckpt
# Number of iterations: 78  loss: 0.00095683127
# model_save ./model_save1/modle.ckpt
# Number of iterations: 78  loss: 0.00040986514
# model_save ./model_save1/modle.ckpt
# Number of iterations: 78  loss: 0.014896278
# model_save ./model_save1/modle.ckpt
# Number of iterations: 79  loss: 0.0020674525
# model_save ./model_save1/modle.ckpt
# Number of iterations: 79  loss: 0.0009305372
# model_save ./model_save1/modle.ckpt
# Number of iterations: 79  loss: 0.00040515303
# model_save ./model_save1/modle.ckpt
# Number of iterations: 79  loss: 0.015685791
# model_save ./model_save1/modle.ckpt
# Number of iterations: 80  loss: 0.0020249821
# model_save ./model_save1/modle.ckpt
# Number of iterations: 80  loss: 0.0009465585
# model_save ./model_save1/modle.ckpt
# Number of iterations: 80  loss: 0.00040127948
# model_save ./model_save1/modle.ckpt
# Number of iterations: 80  loss: 0.0138540985
# model_save ./model_save1/modle.ckpt
# Number of iterations: 81  loss: 0.0019428482
# model_save ./model_save1/modle.ckpt
# Number of iterations: 81  loss: 0.0009011002
# model_save ./model_save1/modle.ckpt
# Number of iterations: 81  loss: 0.00039684903
# model_save ./model_save1/modle.ckpt
# Number of iterations: 81  loss: 0.016411094
# model_save ./model_save1/modle.ckpt
# Number of iterations: 82  loss: 0.0019238886
# model_save ./model_save1/modle.ckpt
# Number of iterations: 82  loss: 0.0009565723
# model_save ./model_save1/modle.ckpt
# Number of iterations: 82  loss: 0.00039203168
# model_save ./model_save1/modle.ckpt
# Number of iterations: 82  loss: 0.012533022
# model_save ./model_save1/modle.ckpt
# Number of iterations: 83  loss: 0.0018172505
# model_save ./model_save1/modle.ckpt
# Number of iterations: 83  loss: 0.0008681391
# model_save ./model_save1/modle.ckpt
# Number of iterations: 83  loss: 0.00039011618
# model_save ./model_save1/modle.ckpt
# Number of iterations: 83  loss: 0.02118628
# model_save ./model_save1/modle.ckpt
# Number of iterations: 84  loss: 0.0018605542
# model_save ./model_save1/modle.ckpt
# Number of iterations: 84  loss: 0.0010585721
# model_save ./model_save1/modle.ckpt
# Number of iterations: 84  loss: 0.00038142334
# model_save ./model_save1/modle.ckpt
# Number of iterations: 84  loss: 0.014754779
# model_save ./model_save1/modle.ckpt
# Number of iterations: 85  loss: 0.0017014921
# model_save ./model_save1/modle.ckpt
# Number of iterations: 85  loss: 0.00094064174
# model_save ./model_save1/modle.ckpt
# Number of iterations: 85  loss: 0.0003912076
# model_save ./model_save1/modle.ckpt
# Number of iterations: 85  loss: 0.049842298
# model_save ./model_save1/modle.ckpt
# Number of iterations: 86  loss: 0.0020136212
# model_save ./model_save1/modle.ckpt
# Number of iterations: 86  loss: 0.0017769528
# model_save ./model_save1/modle.ckpt
# Number of iterations: 86  loss: 0.00037753233
# model_save ./model_save1/modle.ckpt
# Number of iterations: 86  loss: 0.05656639
# model_save ./model_save1/modle.ckpt
# Number of iterations: 87  loss: 0.0023479038
# model_save ./model_save1/modle.ckpt
# Number of iterations: 87  loss: 0.0023366923
# model_save ./model_save1/modle.ckpt
# Number of iterations: 87  loss: 0.00041613236
# model_save ./model_save1/modle.ckpt
# Number of iterations: 87  loss: 0.13167198
# model_save ./model_save1/modle.ckpt
# Number of iterations: 88  loss: 0.0083141485
# model_save ./model_save1/modle.ckpt
# Number of iterations: 88  loss: 0.0049731284
# model_save ./model_save1/modle.ckpt
# Number of iterations: 88  loss: 0.0006703155
# model_save ./model_save1/modle.ckpt
# Number of iterations: 88  loss: 0.07914621
# model_save ./model_save1/modle.ckpt
# Number of iterations: 89  loss: 0.00983133
# model_save ./model_save1/modle.ckpt
# Number of iterations: 89  loss: 0.004487439
# model_save ./model_save1/modle.ckpt
# Number of iterations: 89  loss: 0.00067166396
# model_save ./model_save1/modle.ckpt
# Number of iterations: 89  loss: 0.06919085
# model_save ./model_save1/modle.ckpt
# Number of iterations: 90  loss: 0.04863202
# model_save ./model_save1/modle.ckpt
# Number of iterations: 90  loss: 0.0017751086
# model_save ./model_save1/modle.ckpt
# Number of iterations: 90  loss: 0.0015331936
# model_save ./model_save1/modle.ckpt
# Number of iterations: 90  loss: 0.016973963
# model_save ./model_save1/modle.ckpt
# Number of iterations: 91  loss: 0.015078732
# model_save ./model_save1/modle.ckpt
# Number of iterations: 91  loss: 0.0010249609
# model_save ./model_save1/modle.ckpt
# Number of iterations: 91  loss: 0.0004123914
# model_save ./model_save1/modle.ckpt
# Number of iterations: 91  loss: 0.02517484
# model_save ./model_save1/modle.ckpt
# Number of iterations: 92  loss: 0.026232023
# model_save ./model_save1/modle.ckpt
# Number of iterations: 92  loss: 0.0014577769
# model_save ./model_save1/modle.ckpt
# Number of iterations: 92  loss: 0.0004666404
# model_save ./model_save1/modle.ckpt
# Number of iterations: 92  loss: 0.016234806
# model_save ./model_save1/modle.ckpt
# Number of iterations: 93  loss: 0.013627911
# model_save ./model_save1/modle.ckpt
# Number of iterations: 93  loss: 0.0027003563
# model_save ./model_save1/modle.ckpt
# Number of iterations: 93  loss: 0.00054286834
# model_save ./model_save1/modle.ckpt
# Number of iterations: 93  loss: 0.018294154
# model_save ./model_save1/modle.ckpt
# Number of iterations: 94  loss: 0.01866544
# model_save ./model_save1/modle.ckpt
# Number of iterations: 94  loss: 0.00217691
# model_save ./model_save1/modle.ckpt
# Number of iterations: 94  loss: 0.00041236487
# model_save ./model_save1/modle.ckpt
# Number of iterations: 94  loss: 0.016896568
# model_save ./model_save1/modle.ckpt
# Number of iterations: 95  loss: 0.0060929856
# model_save ./model_save1/modle.ckpt
# Number of iterations: 95  loss: 0.0026390431
# model_save ./model_save1/modle.ckpt
# Number of iterations: 95  loss: 0.0006548415
# model_save ./model_save1/modle.ckpt
# Number of iterations: 95  loss: 0.016566921
# model_save ./model_save1/modle.ckpt
# Number of iterations: 96  loss: 0.009389122
# model_save ./model_save1/modle.ckpt
# Number of iterations: 96  loss: 0.001512596
# model_save ./model_save1/modle.ckpt
# Number of iterations: 96  loss: 0.00037748337
# model_save ./model_save1/modle.ckpt
# Number of iterations: 96  loss: 0.016271707
# model_save ./model_save1/modle.ckpt
# Number of iterations: 97  loss: 0.0022248654
# model_save ./model_save1/modle.ckpt
# Number of iterations: 97  loss: 0.0018415252
# model_save ./model_save1/modle.ckpt
# Number of iterations: 97  loss: 0.0005374258
# model_save ./model_save1/modle.ckpt
# Number of iterations: 97  loss: 0.015647035
# model_save ./model_save1/modle.ckpt
# Number of iterations: 98  loss: 0.003786137
# model_save ./model_save1/modle.ckpt
# Number of iterations: 98  loss: 0.0009750742
# model_save ./model_save1/modle.ckpt
# Number of iterations: 98  loss: 0.00035714236
# model_save ./model_save1/modle.ckpt
# Number of iterations: 98  loss: 0.015388527
# model_save ./model_save1/modle.ckpt
# Number of iterations: 99  loss: 0.0010450878
# model_save ./model_save1/modle.ckpt
# Number of iterations: 99  loss: 0.0012265366
# model_save ./model_save1/modle.ckpt
# Number of iterations: 99  loss: 0.00042331874
# model_save ./model_save1/modle.ckpt
# Number of iterations: 99  loss: 0.014922517
# model_save ./model_save1/modle.ckpt
# Number of iterations: 100  loss: 0.0014781203
# model_save ./model_save1/modle.ckpt
# Number of iterations: 100  loss: 0.0008316622
# model_save ./model_save1/modle.ckpt
# Number of iterations: 100  loss: 0.00035579037
# model_save ./model_save1/modle.ckpt
# Number of iterations: 100  loss: 0.014528439
# model_save ./model_save1/modle.ckpt
# Number of iterations: 101  loss: 0.0011408543
# model_save ./model_save1/modle.ckpt
# Number of iterations: 101  loss: 0.0009294166
# model_save ./model_save1/modle.ckpt
# Number of iterations: 101  loss: 0.00036544944
# model_save ./model_save1/modle.ckpt
# Number of iterations: 101  loss: 0.01428181
# model_save ./model_save1/modle.ckpt
# Number of iterations: 102  loss: 0.0009881844
# model_save ./model_save1/modle.ckpt
# Number of iterations: 102  loss: 0.00088219903
# model_save ./model_save1/modle.ckpt
# Number of iterations: 102  loss: 0.0003496208
# model_save ./model_save1/modle.ckpt
# Number of iterations: 102  loss: 0.013781597
# model_save ./model_save1/modle.ckpt
# Number of iterations: 103  loss: 0.0012967818
# model_save ./model_save1/modle.ckpt
# Number of iterations: 103  loss: 0.00083542604
# model_save ./model_save1/modle.ckpt
# Number of iterations: 103  loss: 0.00034083103
# model_save ./model_save1/modle.ckpt
# Number of iterations: 103  loss: 0.013694012
# model_save ./model_save1/modle.ckpt
# Number of iterations: 104  loss: 0.0009482946
# model_save ./model_save1/modle.ckpt
# Number of iterations: 104  loss: 0.00090701797
# model_save ./model_save1/modle.ckpt
# Number of iterations: 104  loss: 0.00033695783
# model_save ./model_save1/modle.ckpt
# Number of iterations: 104  loss: 0.013165436
# model_save ./model_save1/modle.ckpt
# Number of iterations: 105  loss: 0.0011325997
# model_save ./model_save1/modle.ckpt
# Number of iterations: 105  loss: 0.0008139873
# model_save ./model_save1/modle.ckpt
# Number of iterations: 105  loss: 0.00032831472
# model_save ./model_save1/modle.ckpt
# Number of iterations: 105  loss: 0.013149789
# model_save ./model_save1/modle.ckpt
# Number of iterations: 106  loss: 0.00093195675
# model_save ./model_save1/modle.ckpt
# Number of iterations: 106  loss: 0.0008655064
# model_save ./model_save1/modle.ckpt
# Number of iterations: 106  loss: 0.0003248588
# model_save ./model_save1/modle.ckpt
# Number of iterations: 106  loss: 0.012648945
# model_save ./model_save1/modle.ckpt
# Number of iterations: 107  loss: 0.0009538319
# model_save ./model_save1/modle.ckpt
# Number of iterations: 107  loss: 0.00081439345
# model_save ./model_save1/modle.ckpt
# Number of iterations: 107  loss: 0.00031878336
# model_save ./model_save1/modle.ckpt
# Number of iterations: 107  loss: 0.012668268
# model_save ./model_save1/modle.ckpt
# Number of iterations: 108  loss: 0.00094539305
# model_save ./model_save1/modle.ckpt
# Number of iterations: 108  loss: 0.0008209124
# model_save ./model_save1/modle.ckpt
# Number of iterations: 108  loss: 0.00031576538
# model_save ./model_save1/modle.ckpt
# Number of iterations: 108  loss: 0.012185653
# model_save ./model_save1/modle.ckpt
# Number of iterations: 109  loss: 0.0008833784
# model_save ./model_save1/modle.ckpt
# Number of iterations: 109  loss: 0.0008119421
# model_save ./model_save1/modle.ckpt
# Number of iterations: 109  loss: 0.00031020705
# model_save ./model_save1/modle.ckpt
# Number of iterations: 109  loss: 0.012278393
# model_save ./model_save1/modle.ckpt
# Number of iterations: 110  loss: 0.00092078914
# model_save ./model_save1/modle.ckpt
# Number of iterations: 110  loss: 0.00079799193
# model_save ./model_save1/modle.ckpt
# Number of iterations: 110  loss: 0.00030841937
# model_save ./model_save1/modle.ckpt
# Number of iterations: 110  loss: 0.011736278
# model_save ./model_save1/modle.ckpt
# Number of iterations: 111  loss: 0.00084825716
# model_save ./model_save1/modle.ckpt
# Number of iterations: 111  loss: 0.0007957632
# model_save ./model_save1/modle.ckpt
# Number of iterations: 111  loss: 0.0003029125
# model_save ./model_save1/modle.ckpt
# Number of iterations: 111  loss: 0.012003074
# model_save ./model_save1/modle.ckpt
# Number of iterations: 112  loss: 0.0008718478
# model_save ./model_save1/modle.ckpt
# Number of iterations: 112  loss: 0.00078696996
# model_save ./model_save1/modle.ckpt
# Number of iterations: 112  loss: 0.000301677
# model_save ./model_save1/modle.ckpt
# Number of iterations: 112  loss: 0.011265271
# model_save ./model_save1/modle.ckpt
# Number of iterations: 113  loss: 0.00081442884
# model_save ./model_save1/modle.ckpt
# Number of iterations: 113  loss: 0.000776171
# model_save ./model_save1/modle.ckpt
# Number of iterations: 113  loss: 0.0002963707
# model_save ./model_save1/modle.ckpt
# Number of iterations: 113  loss: 0.0118926875
# model_save ./model_save1/modle.ckpt
# Number of iterations: 114  loss: 0.00083779363
# model_save ./model_save1/modle.ckpt
# Number of iterations: 114  loss: 0.00077873626
# model_save ./model_save1/modle.ckpt
# Number of iterations: 114  loss: 0.0002956818
# model_save ./model_save1/modle.ckpt
# Number of iterations: 114  loss: 0.010712668
# model_save ./model_save1/modle.ckpt
# Number of iterations: 115  loss: 0.0007747158
# model_save ./model_save1/modle.ckpt
# Number of iterations: 115  loss: 0.0007579305
# model_save ./model_save1/modle.ckpt
# Number of iterations: 115  loss: 0.0002898172
# model_save ./model_save1/modle.ckpt
# Number of iterations: 115  loss: 0.012129635
# model_save ./model_save1/modle.ckpt
# Number of iterations: 116  loss: 0.0008265444
# model_save ./model_save1/modle.ckpt
# Number of iterations: 116  loss: 0.0007751545
# model_save ./model_save1/modle.ckpt
# Number of iterations: 116  loss: 0.00029063097
# model_save ./model_save1/modle.ckpt
# Number of iterations: 116  loss: 0.009988806
# model_save ./model_save1/modle.ckpt
# Number of iterations: 117  loss: 0.00073895085
# model_save ./model_save1/modle.ckpt
# Number of iterations: 117  loss: 0.0007380611
# model_save ./model_save1/modle.ckpt
# Number of iterations: 117  loss: 0.00028312838
# model_save ./model_save1/modle.ckpt
# Number of iterations: 117  loss: 0.013400532
# model_save ./model_save1/modle.ckpt
# Number of iterations: 118  loss: 0.00086257386
# model_save ./model_save1/modle.ckpt
# Number of iterations: 118  loss: 0.0007914853
# model_save ./model_save1/modle.ckpt
# Number of iterations: 118  loss: 0.00028666196
# model_save ./model_save1/modle.ckpt
# Number of iterations: 118  loss: 0.009335509
# model_save ./model_save1/modle.ckpt
# Number of iterations: 119  loss: 0.0007459633
# model_save ./model_save1/modle.ckpt
# Number of iterations: 119  loss: 0.00072518416
# model_save ./model_save1/modle.ckpt
# Number of iterations: 119  loss: 0.00027657917
# model_save ./model_save1/modle.ckpt
# Number of iterations: 119  loss: 0.01880152
# model_save ./model_save1/modle.ckpt
# Number of iterations: 120  loss: 0.0010926344
# model_save ./model_save1/modle.ckpt
# Number of iterations: 120  loss: 0.00089865614
# model_save ./model_save1/modle.ckpt
# Number of iterations: 120  loss: 0.00028540715
# model_save ./model_save1/modle.ckpt
# Number of iterations: 120  loss: 0.01288083
# model_save ./model_save1/modle.ckpt
# Number of iterations: 121  loss: 0.0010735404
# model_save ./model_save1/modle.ckpt
# Number of iterations: 121  loss: 0.00084335863
# model_save ./model_save1/modle.ckpt
# Number of iterations: 121  loss: 0.00027219995
# model_save ./model_save1/modle.ckpt
# Number of iterations: 121  loss: 0.04349731
# model_save ./model_save1/modle.ckpt
# Number of iterations: 122  loss: 0.002511659
# model_save ./model_save1/modle.ckpt
# Number of iterations: 122  loss: 0.0014652056
# model_save ./model_save1/modle.ckpt
# Number of iterations: 122  loss: 0.00030366878
# model_save ./model_save1/modle.ckpt
# Number of iterations: 122  loss: 0.044540778
# model_save ./model_save1/modle.ckpt
# Number of iterations: 123  loss: 0.0044430005
# model_save ./model_save1/modle.ckpt
# Number of iterations: 123  loss: 0.0017020194
# model_save ./model_save1/modle.ckpt
# Number of iterations: 123  loss: 0.00029555452
# model_save ./model_save1/modle.ckpt
# Number of iterations: 123  loss: 0.10047929
# model_save ./model_save1/modle.ckpt
# Number of iterations: 124  loss: 0.016879402
# model_save ./model_save1/modle.ckpt
# Number of iterations: 124  loss: 0.0020095177
# model_save ./model_save1/modle.ckpt
# Number of iterations: 124  loss: 0.00052390026
# model_save ./model_save1/modle.ckpt
# Number of iterations: 124  loss: 0.05982191
# model_save ./model_save1/modle.ckpt
# Number of iterations: 125  loss: 0.030442035
# model_save ./model_save1/modle.ckpt
# Number of iterations: 125  loss: 0.0010897351
# model_save ./model_save1/modle.ckpt
# Number of iterations: 125  loss: 0.00031796147
# model_save ./model_save1/modle.ckpt
# Number of iterations: 125  loss: 0.059099954
# model_save ./model_save1/modle.ckpt
# Number of iterations: 126  loss: 0.078911476
# model_save ./model_save1/modle.ckpt
# Number of iterations: 126  loss: 0.002370599
# model_save ./model_save1/modle.ckpt
# Number of iterations: 126  loss: 0.0005280856
# model_save ./model_save1/modle.ckpt
# Number of iterations: 126  loss: 0.015569871
# model_save ./model_save1/modle.ckpt
# Number of iterations: 127  loss: 0.083452605
# model_save ./model_save1/modle.ckpt
# Number of iterations: 127  loss: 0.0051366296
# model_save ./model_save1/modle.ckpt
# Number of iterations: 127  loss: 0.0023065805
# model_save ./model_save1/modle.ckpt
# Number of iterations: 127  loss: 0.020300942
# model_save ./model_save1/modle.ckpt
# Number of iterations: 128  loss: 0.11328031
# model_save ./model_save1/modle.ckpt
# Number of iterations: 128  loss: 0.00764537
# model_save ./model_save1/modle.ckpt
# Number of iterations: 128  loss: 0.0033740362
# model_save ./model_save1/modle.ckpt
# Number of iterations: 128  loss: 0.013534357
# model_save ./model_save1/modle.ckpt
# Number of iterations: 129  loss: 0.036865216
# model_save ./model_save1/modle.ckpt
# Number of iterations: 129  loss: 0.0035938076
# model_save ./model_save1/modle.ckpt
# Number of iterations: 129  loss: 0.0034245085
# model_save ./model_save1/modle.ckpt
# Number of iterations: 129  loss: 0.017062597
# model_save ./model_save1/modle.ckpt
# Number of iterations: 130  loss: 0.045031328
# model_save ./model_save1/modle.ckpt
# Number of iterations: 130  loss: 0.0023647053
# model_save ./model_save1/modle.ckpt
# Number of iterations: 130  loss: 0.0012120204
# model_save ./model_save1/modle.ckpt
# Number of iterations: 130  loss: 0.013755951
# model_save ./model_save1/modle.ckpt
# Number of iterations: 131  loss: 0.0075619793
# model_save ./model_save1/modle.ckpt
# Number of iterations: 131  loss: 0.0017587821
# model_save ./model_save1/modle.ckpt
# Number of iterations: 131  loss: 0.001584231
# model_save ./model_save1/modle.ckpt
# Number of iterations: 131  loss: 0.015282777
# model_save ./model_save1/modle.ckpt
# Number of iterations: 132  loss: 0.013053007
# model_save ./model_save1/modle.ckpt
# Number of iterations: 132  loss: 0.00095068914
# model_save ./model_save1/modle.ckpt
# Number of iterations: 132  loss: 0.00038007344
# model_save ./model_save1/modle.ckpt
# Number of iterations: 132  loss: 0.013712001
# model_save ./model_save1/modle.ckpt
# Number of iterations: 133  loss: 0.0012951476
# model_save ./model_save1/modle.ckpt
# Number of iterations: 133  loss: 0.001148439
# model_save ./model_save1/modle.ckpt
# Number of iterations: 133  loss: 0.00074047985
# model_save ./model_save1/modle.ckpt
# Number of iterations: 133  loss: 0.014348275
# model_save ./model_save1/modle.ckpt
# Number of iterations: 134  loss: 0.004925683
# model_save ./model_save1/modle.ckpt
# Number of iterations: 134  loss: 0.0007744339
# model_save ./model_save1/modle.ckpt
# Number of iterations: 134  loss: 0.00027739382
# model_save ./model_save1/modle.ckpt
# Number of iterations: 134  loss: 0.013405195
# model_save ./model_save1/modle.ckpt
# Number of iterations: 135  loss: 0.0005528325
# model_save ./model_save1/modle.ckpt
# Number of iterations: 135  loss: 0.0009987317
# model_save ./model_save1/modle.ckpt
# Number of iterations: 135  loss: 0.00048418294
# model_save ./model_save1/modle.ckpt
# Number of iterations: 135  loss: 0.013640725
# model_save ./model_save1/modle.ckpt
# Number of iterations: 136  loss: 0.0024793271
# model_save ./model_save1/modle.ckpt
# Number of iterations: 136  loss: 0.0007680546
# model_save ./model_save1/modle.ckpt
# Number of iterations: 136  loss: 0.00027401908
# model_save ./model_save1/modle.ckpt
# Number of iterations: 136  loss: 0.012988476
# model_save ./model_save1/modle.ckpt
# Number of iterations: 137  loss: 0.000516579
# model_save ./model_save1/modle.ckpt
# Number of iterations: 137  loss: 0.0009435471
# model_save ./model_save1/modle.ckpt
# Number of iterations: 137  loss: 0.00038330178
# model_save ./model_save1/modle.ckpt
# Number of iterations: 137  loss: 0.013070001
# model_save ./model_save1/modle.ckpt
# Number of iterations: 138  loss: 0.0015376058
# model_save ./model_save1/modle.ckpt
# Number of iterations: 138  loss: 0.00078365864
# model_save ./model_save1/modle.ckpt
# Number of iterations: 138  loss: 0.00027278735
# model_save ./model_save1/modle.ckpt
# Number of iterations: 138  loss: 0.012550827
# model_save ./model_save1/modle.ckpt
# Number of iterations: 139  loss: 0.00052492187
# model_save ./model_save1/modle.ckpt
# Number of iterations: 139  loss: 0.0009147862
# model_save ./model_save1/modle.ckpt
# Number of iterations: 139  loss: 0.00033195273
# model_save ./model_save1/modle.ckpt
# Number of iterations: 139  loss: 0.012588304
# model_save ./model_save1/modle.ckpt
# Number of iterations: 140  loss: 0.0010971724
# model_save ./model_save1/modle.ckpt
# Number of iterations: 140  loss: 0.0007966254
# model_save ./model_save1/modle.ckpt
# Number of iterations: 140  loss: 0.0002672165
# model_save ./model_save1/modle.ckpt
# Number of iterations: 140  loss: 0.012125915
# model_save ./model_save1/modle.ckpt
# Number of iterations: 141  loss: 0.0005135933
# model_save ./model_save1/modle.ckpt
# Number of iterations: 141  loss: 0.00089485385
# model_save ./model_save1/modle.ckpt
# Number of iterations: 141  loss: 0.00030069207
# model_save ./model_save1/modle.ckpt
# Number of iterations: 141  loss: 0.012178147
# model_save ./model_save1/modle.ckpt
# Number of iterations: 142  loss: 0.0008608755
# model_save ./model_save1/modle.ckpt
# Number of iterations: 142  loss: 0.00080297294
# model_save ./model_save1/modle.ckpt
# Number of iterations: 142  loss: 0.00025938355
# model_save ./model_save1/modle.ckpt
# Number of iterations: 142  loss: 0.011722914
# model_save ./model_save1/modle.ckpt
# Number of iterations: 143  loss: 0.0004894281
# model_save ./model_save1/modle.ckpt
# Number of iterations: 143  loss: 0.0008777477
# model_save ./model_save1/modle.ckpt
# Number of iterations: 143  loss: 0.0002792947
# model_save ./model_save1/modle.ckpt
# Number of iterations: 143  loss: 0.01183628
# model_save ./model_save1/modle.ckpt
# Number of iterations: 144  loss: 0.0007225577
# model_save ./model_save1/modle.ckpt
# Number of iterations: 144  loss: 0.0008029518
# model_save ./model_save1/modle.ckpt
# ...
# Number of iterations: 152  loss: 0.00076591223
# model_save ./model_save1/modle.ckpt
# Number of iterations: 152  loss: 0.00022151765
# model_save ./model_save1/modle.ckpt
# Number of iterations: 152  loss: 0.009292677
# model_save ./model_save1/modle.ckpt
# Number of iterations: 153  loss: 0.0003958339
# model_save ./model_save1/modle.ckpt
# Number of iterations: 153  loss: 0.0007859861
# model_save ./model_save1/modle.ckpt
# Number of iterations: 153  loss: 0.00022838905
# model_save ./model_save1/modle.ckpt
# Number of iterations: 153  loss: 0.01375034
# model_save ./model_save1/modle.ckpt
# Number of iterations: 154  loss: 0.0008646054
# model_save ./model_save1/modle.ckpt
# Number of iterations: 154  loss: 0.00076060684
# model_save ./model_save1/modle.ckpt
# Number of iterations: 154  loss: 0.00021624663
# model_save ./model_save1/modle.ckpt
# Number of iterations: 154  loss: 0.009002417
# model_save ./model_save1/modle.ckpt
# Number of iterations: 155  loss: 0.0006429248
# model_save ./model_save1/modle.ckpt
# Number of iterations: 155  loss: 0.0007517317
# model_save ./model_save1/modle.ckpt
# Number of iterations: 155  loss: 0.00022511304
# model_save ./model_save1/modle.ckpt
# Number of iterations: 155  loss: 0.020989256
# model_save ./model_save1/modle.ckpt
# Number of iterations: 156  loss: 0.0018547262
# model_save ./model_save1/modle.ckpt
# Number of iterations: 156  loss: 0.0007804649
# model_save ./model_save1/modle.ckpt
# Number of iterations: 156  loss: 0.00021488978
# model_save ./model_save1/modle.ckpt
# Number of iterations: 156  loss: 0.014948533
# model_save ./model_save1/modle.ckpt
# Number of iterations: 157  loss: 0.0023555188
# model_save ./model_save1/modle.ckpt
# Number of iterations: 157  loss: 0.0006952073
# model_save ./model_save1/modle.ckpt
# Number of iterations: 157  loss: 0.00022746847
# model_save ./model_save1/modle.ckpt
# Number of iterations: 157  loss: 0.049214847
# model_save ./model_save1/modle.ckpt
# Number of iterations: 158  loss: 0.006910018
# model_save ./model_save1/modle.ckpt
# Number of iterations: 158  loss: 0.00085765164
# model_save ./model_save1/modle.ckpt
# Number of iterations: 158  loss: 0.00023196315
# model_save ./model_save1/modle.ckpt
# Number of iterations: 158  loss: 0.045015387
# model_save ./model_save1/modle.ckpt
# Number of iterations: 159  loss: 0.013104353
# model_save ./model_save1/modle.ckpt
# Number of iterations: 159  loss: 0.00066740456
# model_save ./model_save1/modle.ckpt
# Number of iterations: 159  loss: 0.00026214917
# model_save ./model_save1/modle.ckpt
# Number of iterations: 159  loss: 0.08278917
# model_save ./model_save1/modle.ckpt
# Number of iterations: 160  loss: 0.033135355
# model_save ./model_save1/modle.ckpt
# Number of iterations: 160  loss: 0.0007261929
# model_save ./model_save1/modle.ckpt
# Number of iterations: 160  loss: 0.00040860721
# model_save ./model_save1/modle.ckpt
# Number of iterations: 160  loss: 0.037173633
# model_save ./model_save1/modle.ckpt
# Number of iterations: 161  loss: 0.05060421
# model_save ./model_save1/modle.ckpt
# Number of iterations: 161  loss: 0.0012529278
# model_save ./model_save1/modle.ckpt
# Number of iterations: 161  loss: 0.0008154737
# model_save ./model_save1/modle.ckpt
# Number of iterations: 161  loss: 0.040942263
# model_save ./model_save1/modle.ckpt
# Number of iterations: 162  loss: 0.07785249
# model_save ./model_save1/modle.ckpt
# Number of iterations: 162  loss: 0.0018473482
# model_save ./model_save1/modle.ckpt
# Number of iterations: 162  loss: 0.0016236715
# model_save ./model_save1/modle.ckpt
# Number of iterations: 162  loss: 0.013090477
# model_save ./model_save1/modle.ckpt
# Number of iterations: 163  loss: 0.04470113
# model_save ./model_save1/modle.ckpt
# Number of iterations: 163  loss: 0.0028160394
# model_save ./model_save1/modle.ckpt
# Number of iterations: 163  loss: 0.0021120429
# model_save ./model_save1/modle.ckpt
# Number of iterations: 163  loss: 0.019181112
# model_save ./model_save1/modle.ckpt
# Number of iterations: 164  loss: 0.044113915
# model_save ./model_save1/modle.ckpt
# Number of iterations: 164  loss: 0.0017676632
# model_save ./model_save1/modle.ckpt
# Number of iterations: 164  loss: 0.0012726544
# model_save ./model_save1/modle.ckpt
# Number of iterations: 164  loss: 0.012242334
# model_save ./model_save1/modle.ckpt
# Number of iterations: 165  loss: 0.01021542
# model_save ./model_save1/modle.ckpt
# Number of iterations: 165  loss: 0.0018704551
# model_save ./model_save1/modle.ckpt
# Number of iterations: 165  loss: 0.0012714354
# model_save ./model_save1/modle.ckpt
# Number of iterations: 165  loss: 0.015157989
# model_save ./model_save1/modle.ckpt
# Number of iterations: 166  loss: 0.011415232
# model_save ./model_save1/modle.ckpt
# Number of iterations: 166  loss: 0.0008624789
# model_save ./model_save1/modle.ckpt
# Number of iterations: 166  loss: 0.00037105283
# model_save ./model_save1/modle.ckpt
# Number of iterations: 166  loss: 0.012635382
# model_save ./model_save1/modle.ckpt
# Number of iterations: 167  loss: 0.0013327308
# model_save ./model_save1/modle.ckpt
# Number of iterations: 167  loss: 0.0012102971
# model_save ./model_save1/modle.ckpt
# Number of iterations: 167  loss: 0.0005673454
# model_save ./model_save1/modle.ckpt
# Number of iterations: 167  loss: 0.013606361
# model_save ./model_save1/modle.ckpt
# Number of iterations: 168  loss: 0.0031305107
# model_save ./model_save1/modle.ckpt
# Number of iterations: 168  loss: 0.00067198614
# model_save ./model_save1/modle.ckpt
# Number of iterations: 168  loss: 0.00021544866
# model_save ./model_save1/modle.ckpt
# Number of iterations: 168  loss: 0.012455531
# model_save ./model_save1/modle.ckpt
# Number of iterations: 169  loss: 0.00038160462
# model_save ./model_save1/modle.ckpt
# Number of iterations: 169  loss: 0.0009456537
# model_save ./model_save1/modle.ckpt
# Number of iterations: 169  loss: 0.000338635
# model_save ./model_save1/modle.ckpt
# Number of iterations: 169  loss: 0.012795689
# model_save ./model_save1/modle.ckpt
# Number of iterations: 170  loss: 0.0012631575
# model_save ./model_save1/modle.ckpt
# Number of iterations: 170  loss: 0.0006886345
# model_save ./model_save1/modle.ckpt
# Number of iterations: 170  loss: 0.00021338579
# model_save ./model_save1/modle.ckpt
# Number of iterations: 170  loss: 0.012071032
# model_save ./model_save1/modle.ckpt
# Number of iterations: 171  loss: 0.00040471915
# model_save ./model_save1/modle.ckpt
# Number of iterations: 171  loss: 0.0008424116
# model_save ./model_save1/modle.ckpt
# Number of iterations: 171  loss: 0.0002652434
# model_save ./model_save1/modle.ckpt
# Number of iterations: 171  loss: 0.012235406
# model_save ./model_save1/modle.ckpt
# Number of iterations: 172  loss: 0.00074655097
# model_save ./model_save1/modle.ckpt
# Number of iterations: 172  loss: 0.00072327664
# model_save ./model_save1/modle.ckpt
# Number of iterations: 172  loss: 0.00021787237
# model_save ./model_save1/modle.ckpt
# Number of iterations: 172  loss: 0.011657819
# model_save ./model_save1/modle.ckpt
# Number of iterations: 173  loss: 0.00043620737
# model_save ./model_save1/modle.ckpt
# Number of iterations: 173  loss: 0.0007973309
# model_save ./model_save1/modle.ckpt
# Number of iterations: 173  loss: 0.00023605053
# model_save ./model_save1/modle.ckpt
# Number of iterations: 173  loss: 0.01179425
# model_save ./model_save1/modle.ckpt
# Number of iterations: 174  loss: 0.00056322716
# model_save ./model_save1/modle.ckpt
# Number of iterations: 174  loss: 0.0007438531
# model_save ./model_save1/modle.ckpt
# Number of iterations: 174  loss: 0.00021633734
# model_save ./model_save1/modle.ckpt
# Number of iterations: 174  loss: 0.011265758
# model_save ./model_save1/modle.ckpt
# Number of iterations: 175  loss: 0.0004253008
# model_save ./model_save1/modle.ckpt
# Number of iterations: 175  loss: 0.000774248
# model_save ./model_save1/modle.ckpt
# Number of iterations: 175  loss: 0.00022134036
# model_save ./model_save1/modle.ckpt
# Number of iterations: 175  loss: 0.011437218
# model_save ./model_save1/modle.ckpt
# Number of iterations: 176  loss: 0.00048224107
# model_save ./model_save1/modle.ckpt
# Number of iterations: 176  loss: 0.00075071986
# model_save ./model_save1/modle.ckpt
# Number of iterations: 176  loss: 0.00021166682
# model_save ./model_save1/modle.ckpt
# Number of iterations: 176  loss: 0.010900802
# model_save ./model_save1/modle.ckpt
# Number of iterations: 177  loss: 0.000397505
# model_save ./model_save1/modle.ckpt
# Number of iterations: 177  loss: 0.00075964344
# model_save ./model_save1/modle.ckpt
# Number of iterations: 177  loss: 0.00021233087
# model_save ./model_save1/modle.ckpt
# Number of iterations: 177  loss: 0.011158469
# model_save ./model_save1/modle.ckpt
# Number of iterations: 178  loss: 0.0004409867
# model_save ./model_save1/modle.ckpt
# Number of iterations: 178  loss: 0.00074850564
# model_save ./model_save1/modle.ckpt
# Number of iterations: 178  loss: 0.00020616259
# model_save ./model_save1/modle.ckpt
# Number of iterations: 178  loss: 0.010550991
# model_save ./model_save1/modle.ckpt
# Number of iterations: 179  loss: 0.00036690946
# model_save ./model_save1/modle.ckpt
# Number of iterations: 179  loss: 0.0007478939
# model_save ./model_save1/modle.ckpt
# Number of iterations: 179  loss: 0.00020600254
# model_save ./model_save1/modle.ckpt
# Number of iterations: 179  loss: 0.010970374
# model_save ./model_save1/modle.ckpt
# Number of iterations: 180  loss: 0.00042061866
# model_save ./model_save1/modle.ckpt
# Number of iterations: 180  loss: 0.000741043
# model_save ./model_save1/modle.ckpt
# Number of iterations: 180  loss: 0.00020081465
# model_save ./model_save1/modle.ckpt
# Number of iterations: 180  loss: 0.010189645
# model_save ./model_save1/modle.ckpt
# Number of iterations: 181  loss: 0.0003380465
# model_save ./model_save1/modle.ckpt
# Number of iterations: 181  loss: 0.00073640066
# model_save ./model_save1/modle.ckpt
# Number of iterations: 181  loss: 0.00020120037
# model_save ./model_save1/modle.ckpt
# Number of iterations: 181  loss: 0.010917441
# model_save ./model_save1/modle.ckpt
# Number of iterations: 182  loss: 0.00041829358
# model_save ./model_save1/modle.ckpt
# Number of iterations: 182  loss: 0.0007311793
# model_save ./model_save1/modle.ckpt
# Number of iterations: 182  loss: 0.00019592191
# model_save ./model_save1/modle.ckpt
# Number of iterations: 182  loss: 0.009769202
# model_save ./model_save1/modle.ckpt
# Number of iterations: 183  loss: 0.00031306216
# model_save ./model_save1/modle.ckpt
# Number of iterations: 183  loss: 0.00072353333
# model_save ./model_save1/modle.ckpt
# Number of iterations: 183  loss: 0.00019750766
# model_save ./model_save1/modle.ckpt
# Number of iterations: 183  loss: 0.011131822
# model_save ./model_save1/modle.ckpt
# Number of iterations: 184  loss: 0.0004456619
# model_save ./model_save1/modle.ckpt
# Number of iterations: 184  loss: 0.0007216797
# model_save ./model_save1/modle.ckpt
# Number of iterations: 184  loss: 0.00019151521
# model_save ./model_save1/modle.ckpt
# Number of iterations: 184  loss: 0.009225478
# model_save ./model_save1/modle.ckpt
# Number of iterations: 185  loss: 0.00030342644
# model_save ./model_save1/modle.ckpt
# Number of iterations: 185  loss: 0.00070701516
# model_save ./model_save1/modle.ckpt
# Number of iterations: 185  loss: 0.00019496707
# model_save ./model_save1/modle.ckpt
# Number of iterations: 185  loss: 0.012042966
# model_save ./model_save1/modle.ckpt
# Number of iterations: 186  loss: 0.0005546372
# model_save ./model_save1/modle.ckpt
# Number of iterations: 186  loss: 0.0007172684
# model_save ./model_save1/modle.ckpt
# Number of iterations: 186  loss: 0.00018770747
# model_save ./model_save1/modle.ckpt
# Number of iterations: 186  loss: 0.00864588
# model_save ./model_save1/modle.ckpt
# Number of iterations: 187  loss: 0.00038109036
# model_save ./model_save1/modle.ckpt
# Number of iterations: 187  loss: 0.0006815933
# model_save ./model_save1/modle.ckpt
# Number of iterations: 187  loss: 0.00019443319
# model_save ./model_save1/modle.ckpt
# Number of iterations: 187  loss: 0.015304063
# model_save ./model_save1/modle.ckpt
# Number of iterations: 188  loss: 0.0009761377
# model_save ./model_save1/modle.ckpt
# Number of iterations: 188  loss: 0.00073064846
# model_save ./model_save1/modle.ckpt
# Number of iterations: 188  loss: 0.00018589923
# model_save ./model_save1/modle.ckpt
# Number of iterations: 188  loss: 0.009739957
# model_save ./model_save1/modle.ckpt
# Number of iterations: 189  loss: 0.0009791374
# model_save ./model_save1/modle.ckpt
# Number of iterations: 189  loss: 0.00063804496
# model_save ./model_save1/modle.ckpt
# Number of iterations: 189  loss: 0.00019963349
# model_save ./model_save1/modle.ckpt
# Number of iterations: 189  loss: 0.027925707
# model_save ./model_save1/modle.ckpt
# Number of iterations: 190  loss: 0.0029031062
# model_save ./model_save1/modle.ckpt
# Number of iterations: 190  loss: 0.0007986799
# model_save ./model_save1/modle.ckpt
# Number of iterations: 190  loss: 0.00019555044
# model_save ./model_save1/modle.ckpt
# Number of iterations: 190  loss: 0.023089772
# model_save ./model_save1/modle.ckpt
# Number of iterations: 191  loss: 0.004725046
# model_save ./model_save1/modle.ckpt
# Number of iterations: 191  loss: 0.0005942679
# model_save ./model_save1/modle.ckpt
# Number of iterations: 191  loss: 0.00022250305
# model_save ./model_save1/modle.ckpt
# Number of iterations: 191  loss: 0.06391534
# model_save ./model_save1/modle.ckpt
# Number of iterations: 192  loss: 0.012859254
# model_save ./model_save1/modle.ckpt
# Number of iterations: 192  loss: 0.0008665973
# model_save ./model_save1/modle.ckpt
# Number of iterations: 192  loss: 0.0002573865
# model_save ./model_save1/modle.ckpt
# Number of iterations: 192  loss: 0.045552276
# model_save ./model_save1/modle.ckpt
# Number of iterations: 193  loss: 0.023216145
# model_save ./model_save1/modle.ckpt
# Number of iterations: 193  loss: 0.00060756924
# model_save ./model_save1/modle.ckpt
# Number of iterations: 193  loss: 0.00035232445
# model_save ./model_save1/modle.ckpt
# Number of iterations: 193  loss: 0.062224668
# model_save ./model_save1/modle.ckpt
# Number of iterations: 194  loss: 0.047705755
# model_save ./model_save1/modle.ckpt
# Number of iterations: 194  loss: 0.0007098019
# model_save ./model_save1/modle.ckpt
# Number of iterations: 194  loss: 0.00072597567
# model_save ./model_save1/modle.ckpt
# Number of iterations: 194  loss: 0.018986953
# model_save ./model_save1/modle.ckpt
# Number of iterations: 195  loss: 0.04824518
# model_save ./model_save1/modle.ckpt
# Number of iterations: 195  loss: 0.0015522455
# model_save ./model_save1/modle.ckpt
# Number of iterations: 195  loss: 0.0011660493
# model_save ./model_save1/modle.ckpt
# Number of iterations: 195  loss: 0.025597144
# model_save ./model_save1/modle.ckpt
# Number of iterations: 196  loss: 0.05757017
# model_save ./model_save1/modle.ckpt
# Number of iterations: 196  loss: 0.0018669876
# model_save ./model_save1/modle.ckpt
# Number of iterations: 196  loss: 0.0013115841
# model_save ./model_save1/modle.ckpt
# Number of iterations: 196  loss: 0.011312262
# model_save ./model_save1/modle.ckpt
# Number of iterations: 197  loss: 0.020010084
# model_save ./model_save1/modle.ckpt
# Number of iterations: 197  loss: 0.002365247
# model_save ./model_save1/modle.ckpt
# Number of iterations: 197  loss: 0.0014602091
# model_save ./model_save1/modle.ckpt
# Number of iterations: 197  loss: 0.015959132
# model_save ./model_save1/modle.ckpt
# Number of iterations: 198  loss: 0.018049005
# model_save ./model_save1/modle.ckpt
# Number of iterations: 198  loss: 0.0012738099
# model_save ./model_save1/modle.ckpt
# Number of iterations: 198  loss: 0.0005551627
# model_save ./model_save1/modle.ckpt
# Number of iterations: 198  loss: 0.011743596
# model_save ./model_save1/modle.ckpt
# Number of iterations: 199  loss: 0.0025006323
# model_save ./model_save1/modle.ckpt
# Number of iterations: 199  loss: 0.0014864482
# model_save ./model_save1/modle.ckpt
# Number of iterations: 199  loss: 0.00066102925
# model_save ./model_save1/modle.ckpt
# Number of iterations: 199  loss: 0.0138080325
# model_save ./model_save1/modle.ckpt
# Number of iterations: 200  loss: 0.003660694
# model_save ./model_save1/modle.ckpt
# Number of iterations: 200  loss: 0.00068979734
# model_save ./model_save1/modle.ckpt
# Number of iterations: 200  loss: 0.00020897831
# model_save ./model_save1/modle.ckpt
# Number of iterations: 200  loss: 0.011738526
# model_save ./model_save1/modle.ckpt
# The train has finished
# 804

# %%
#———————————————————预测模型—————————————————————
def prediction():
    with tf.variable_scope("sec_lstm",reuse=True):
        pred,_=lstm(1)    #预测时只输入[1,time_step,input_size]的测试数据
    saver=tf.train.Saver(tf.global_variables())
    with tf.Session() as sess:
        #参数恢复
        saver.restore(sess, './model_save1/modle.ckpt') #第二个参数是保存的地址，可以修改为自己本地的保存地址
        #I run the code in windows 10,so use  'model_save1\\modle.ckpt'
        #if you run it in Linux,please use  'model_save1/modle.ckpt'
        
        #取训练集最后一行为测试样本。shape = [1,time_step,input_size]
        prev_seq=train_x[-1]
        predict=[]
        #得到之后的100个预测结果
        for i in range(100):  #预测100个数值
            next_seq=sess.run(pred,feed_dict={X:[prev_seq]})
            predict.append(next_seq[-1])
            #每次得到最后一个时间步的预测结果，与之前的数据加在一起，形成新的测试数据
            prev_seq=np.vstack((prev_seq[1:],next_seq[-1]))
        #以折线图展示结果
        plt.figure(figsize = (20,20)) #图像大小为8*8英寸
        #设置背景风格
        sns.set_style(style = 'whitegrid') #详细参数看seaborn的API  http://seaborn.pydata.org/api.html
        #设置字体
        sns.set_context(context = 'poster',font_scale = 1)
        plt.title('lstm_rnn_prediction')
        predict = np.squeeze(predict)#减少数据维度
        predict = predict*np.std(data)+np.mean(data)#恢复先前价格
        plt.plot(list(range(len(data))), data, color='b',label = 'raw data') #这是原来股票的价格走势，用蓝色曲线表示
        plt.plot(list(range(len(data), len(data) + len(predict))), predict, color='r',label = 'predict trend') #预测未来的价格走势用红色表示
        plt.legend(loc = 'best')
        plt.xlabel('trend')
        plt.show()
#fig.add_subplot(1,2,2)

# %%
prediction()
# Out:
# INFO:tensorflow:Restoring parameters from ./model_save1/modle.ckpt

# %%
# Out:
# [[ 1.24506664]
#  [ 1.25369476]
#  [ 1.22563565]
#  ...
#  [-1.7968064 ]
#  [-1.64608615]
#  [-1.82576378]]

# %%
# Out:
# [247.193 247.558 246.371 ... 118.511 124.887 117.286]

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-39-40a5e4e9c09c> in <module>
# ----> 1 print(predict)
#
# NameError: name 'predict' is not defined
